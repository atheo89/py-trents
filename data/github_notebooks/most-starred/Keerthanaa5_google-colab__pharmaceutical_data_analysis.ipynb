# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthanaa5/google-colab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objective:
#
# To analyze and visualize pharmaceutical data to identify the most commonly treated medical conditions and the distribution of drug classes, providing insights into healthcare priorities and treatment trends.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data =pd.read_csv('/content/drugs_side_effects_drugs_com.csv')
data.head()
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
data.shape
# Out:
# (2966, 135)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2966, step=1)

# %%
data.columns
# Out:
# Index(['drug_name', 'medical_condition', 'side_effects', 'generic_name',
#        'drug_classes', 'brand_names', 'activity', 'rx_otc',
#        'pregnancy_category', 'csa',
#        ...
#        'Unnamed: 125', 'Unnamed: 126', 'Unnamed: 127', 'Unnamed: 128',
#        'Unnamed: 129', 'Unnamed: 130', 'Unnamed: 131', 'Unnamed: 132',
#        'Unnamed: 133', 'Unnamed: 134'],
#       dtype='object', length=135)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2966 entries, 0 to 2965
# Columns: 135 entries, drug_name to Unnamed: 134
# dtypes: float64(3), object(132)
# memory usage: 3.1+ MB

# %%
data.describe()
# Out:
#        Unnamed: 128  Unnamed: 131  Unnamed: 132
# count           0.0           0.0           0.0
# mean            NaN           NaN           NaN
# std             NaN           NaN           NaN
# min             NaN           NaN           NaN
# 25%             NaN           NaN           NaN
# 50%             NaN           NaN           NaN
# 75%             NaN           NaN           NaN
# max             NaN           NaN           NaN

# %%
data.isnull().sum()
# Out:
# drug_name               1
# medical_condition       0
# side_effects          124
# generic_name           44
# drug_classes           83
#                      ...
# Unnamed: 130         2965
# Unnamed: 131         2966
# Unnamed: 132         2966
# Unnamed: 133         2965
# Unnamed: 134         2965
# Length: 135, dtype: int64

# %%
data_cleaned= data.dropna()

# %%
data.head()
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
data.isnull().sum()
# Out:
# drug_name               1
# medical_condition       0
# side_effects          124
# generic_name           44
# drug_classes           83
#                      ...
# Unnamed: 130         2965
# Unnamed: 131         2966
# Unnamed: 132         2966
# Unnamed: 133         2965
# Unnamed: 134         2965
# Length: 135, dtype: int64

# %%
data =data.dropna(axis =1, how ='all')

# %%
data.shape
# Out:
# (2966, 132)

# %%
data.isnull().sum()
# Out:
# drug_name               1
# medical_condition       0
# side_effects          124
# generic_name           44
# drug_classes           83
#                      ...
# Unnamed: 127         2965
# Unnamed: 129         2965
# Unnamed: 130         2965
# Unnamed: 133         2965
# Unnamed: 134         2965
# Length: 132, dtype: int64

# %%
columns_to_fill = ['side_effects', 'generic_name', 'drug_name', 'drug_classes']

for col in columns_to_fill:
    if data[col].isnull().sum() > 0:
        mode_value = data[col].mode()[0]
        data[col].fillna(mode_value, inplace=True)

# %%
data.isnull().sum()
# Out:
# drug_name               0
# medical_condition       0
# side_effects            0
# generic_name            0
# drug_classes            0
#                      ...
# Unnamed: 127         2965
# Unnamed: 129         2965
# Unnamed: 130         2965
# Unnamed: 133         2965
# Unnamed: 134         2965
# Length: 132, dtype: int64

# %%
data =data.dropna(axis =1, how ='any')

# %%
data.columns
# Out:
# Index(['drug_name', 'medical_condition', 'side_effects', 'generic_name',
#        'drug_classes'],
#       dtype='object')

# %%
data.shape
# Out:
# (2966, 5)

# %%
data.describe()
# Out:
#                                                 drug_name medical_condition  \
# count                                                2966              2966
# unique                                               2913                49
# top     re provided authorization to proceed for Phase...              Pain
# freq                                                   35               264
#
#                                              side_effects  \
# count                                                2966
# unique                                               2761
# top      2021 Sanofi announced it will not pursue the ...
# freq                                                  158
#
#                                              generic_name  \
# count                                                2966
# unique                                               1393
# top      two weeks after the second injection. SCB-201...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2966 entries, 0 to 2965
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   drug_name          2966 non-null   object
#  1   medical_condition  2966 non-null   object
#  2   side_effects       2966 non-null   object
#  3   generic_name       2966 non-null   object
#  4   drug_classes       2966 non-null   object
# dtypes: object(5)
# memory usage: 116.0+ KB

# %%
data.head(10)
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
# 5       Aldactone              Acne
# 6       tretinoin              Acne
# 7    isotretinoin              Acne
# 8         Bactrim              Acne
# 9         Retin-A              Acne
#
#                                         side_effects  \
# 0  (hives, difficult breathing, swelling in your ...
# 1  hives ; difficulty breathing; swelling of your...
# 2  skin rash, fever, swollen glands, flu-like sym...
# 3  problems with your vision or hearing; muscle o...
# 4  hives ; difficult breathing; swelling of your ...
# 5  hives ; difficulty breathing; swelling of your...
# 6  hives ; difficult breathing; swelling of your ...
# 7  problems with your vision or hearing; muscle o...
# 8  skin rash, fever, swollen glands, joint pain, ...
# ...

# %%
sns.countplot(y ='medical_condition', data =data , order=data['medical_condition'].value_counts().index[:10])
plt.title('top 10 medical conditions treated')
plt.show()

# %% [markdown]
#  Key Observations:
#
#   1.	Pain is the most commonly treated medical condition in the dataset, with over 250 drug entries, highlighting its widespread nature and the variety of treatments available.
#
#   2.	Colds & Flu and Acne follow closely, reflecting the common and recurring nature of these conditions, especially among general and dermatological care.
#
#   3.	Chronic conditions such as Hypertension, Osteoarthritis, and Diabetes (Type 2) also appear prominently, indicating a strong pharmaceutical focus on long-term disease management.
#
#   4.	Conditions like AIDS/HIV, Eczema, and Psoriasis are also in the top 10, suggesting significant medical and research attention in immune-related and skin conditions.
#
#   5.	The plot also shows that while some conditions have a large variety of treatment options (like pain), others may have fewer, possibly due to complexity in treatment or limited drug development.

# %%
top_classes = data['drug_classes'].value_counts().head(10)
plt.figure(figsize=(7,7))
plt.pie(top_classes, labels=top_classes.index, autopct='%1.1f%%', startangle=140)
plt.title("Top 10 Drug Classes (Pie Chart)")
plt.axis('equal')
plt.show()

# %% [markdown]
# Insight:   The dominance of upper respiratory and topical treatments suggests a strong pharmaceutical focus on widely experienced, high-frequency conditions.

# %%
plt.figure(figsize=(10, 6))
top_conditions = data['medical_condition'].value_counts().head(10)
top_conditions_df = top_conditions.reset_index()
top_conditions_df.columns = ['medical_condition', 'count']
sns.barplot(x='count', y='medical_condition', data=top_conditions_df)
plt.title("Top 10 Medical Conditions")
plt.xlabel("Number of Drugs")
plt.ylabel("Medical Condition")
plt.tight_layout()
plt.show()

# %% [markdown]
# This visualization emphasizes that:
#
#   •	Acute conditions (Pain, Colds & Flu) have the highest number of drugs, indicating frequent treatment needs.
#
#   •	Chronic and lifestyle-related conditions (Hypertension, Diabetes) also make up a significant share, showing the impact of modern health trends.

# %%
grouped = data.groupby('medical_condition')['drug_name'].unique()
print(grouped.head())
# Out:
# medical_condition
#  INO-4800. MRT5500 Vaccine platform: mRNA vaccine On September 28    [re provided authorization to proceed for Phas...
# ADHD                                                                 [Vyvanse, Adderall, Adderall XR, Concerta, lis...
# AIDS/HIV                                                             [Truvada, Biktarvy, Triumeq, Genvoya, Stribild...
# Acne                                                                 [doxycycline, spironolactone, minocycline, Acc...
# Allergies                                                            [hydroxyzine, levocetirizine, loratadine, Xyza...
# Name: drug_name, dtype: object

# %% [markdown]
# Final Project Conclusion:
#
# This analysis revealed that Pain, Colds & Flu, and Acne are the most commonly treated medical conditions, indicating a strong pharmaceutical focus on frequent and acute health issues. Chronic conditions like Hypertension and Diabetes also show significant drug coverage, reflecting long-term treatment needs.
#
# From the pie chart, Upper Respiratory Combinations, Topical Acne Agents, and NSAIDs were among the most common drug classes, showing a diverse range of treatments targeting both general and specialized conditions.
#
# In summary, the visualizations highlight the widespread and strategic distribution of drugs across common health conditions, offering insights into healthcare priorities and pharmaceutical trends.
