# %%
import pandas as pd

df = pd.read_csv('/home/gui/hf_dev/datatrove/blogpost/data/decont_ngrams-per_dump.csv')

# %%
df = df.groupby(["ngram", "task"], as_index=False)["count"].sum().sort_values("count", ascending=False)

# %%
df.to_csv('/home/gui/hf_dev/datatrove/blogpost/data/decont_ngrams-global.csv', index=False)
