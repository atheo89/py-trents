# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("/kaggle/input/ecommerce-sales-data/ecommerce_sales_data.csv")

# Convert Order Date to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Extract Year and Month for trend analysis
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month

# %%
df

# %%
df.info()

# %% [markdown]
# ## Category-wise Sales & Profit

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Category', y='Sales', data=df, estimator=sum, palette='viridis')
plt.title("Total Sales by Category")
plt.show()

plt.figure(figsize=(10,6))
sns.barplot(x='Category', y='Profit', data=df, estimator=sum, palette='magma')
plt.title("Total Profit by Category")
plt.show()

# %% [markdown]
# ## Regional Performance

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Region', y='Sales', data=df, estimator=sum, palette='coolwarm')
plt.title("Regional Sales Performance")
plt.show()

plt.figure(figsize=(10,6))
sns.barplot(x='Region', y='Profit', data=df, estimator=sum, palette='Set2')
plt.title("Regional Profit Performance")
plt.show()

# %% [markdown]
# ## Monthly Seasonality

# %%
monthly_sales = df.groupby(['Year','Month'])['Sales'].sum().reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(x='Month', y='Sales', hue='Year', data=monthly_sales, marker='o')
plt.title("Monthly Sales Trends (2022–2024)")
plt.show()

# %% [markdown]
# ## Top Products by Sales

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))
sns.barplot(x=top_products.values, y=top_products.index, palette='plasma')
plt.title("Top 10 Products by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Product")
plt.show()

# %% [markdown]
# ## Profit Margin Analysis

# %%
df['Profit Margin %'] = (df['Profit'] / df['Sales']) * 100

plt.figure(figsize=(10,6))
sns.boxplot(x='Category', y='Profit Margin %', data=df, palette='Set3')
plt.title("Profit Margin Distribution by Category")
plt.show()
