# %% [markdown]
# ![Domain](https://img.shields.io/badge/Domain-FinTech-black)
# ![Task](https://img.shields.io/badge/Task-Fraud%20Detection-red)
# ![Type](https://img.shields.io/badge/Data-Structured-blue)
# ![Imbalance](https://img.shields.io/badge/Class%20Imbalance-Extreme-orange)
# ![Status](https://img.shields.io/badge/Status-Cleaned%20%26%20Prepared-success)

# %% [markdown]
# ---

# %% [markdown]
# # 🗂Call Libraries

# %%
from pandas import read_csv

# %% [markdown]
# ---

# %% [markdown]
# # 📝Load dataset's

# %%
df_clean = read_csv(r"/kaggle/input/datasets/bornaetminan/credit-card-fraud-detectioncleaned-and-ml-ready/creditcard_cleaned.csv")
df_ml_ready = read_csv(r'/kaggle/input/datasets/bornaetminan/credit-card-fraud-detectioncleaned-and-ml-ready/creditcard_ml_ready.csv')
print('df_clean \n')
df_clean
print('df_ml_ready \n')
df_ml_ready

# %% [markdown]
# ---

# %% [markdown]
# # 📖Showing Information

# %%
print('df_clean describe \n')
df_clean.describe()
print('df_ml_ready describe \n')
df_ml_ready.describe()

# %%
print('df_clean info \n')
df_clean.info()
print('df_ml_ready info \n')
df_ml_ready.info()

# %%
print('df_clean the number of null item\'s\n')
df_clean.isnull().sum()
print('df_ml_ready the number of null item\'s')
df_ml_ready.isnull().sum()

# %% [markdown]
# ---
