# %% [markdown]
# # 1

# %% [markdown]
# Tomato_mosaic_virus
# Target_Spot
# Bacterial_spot
# Tomato_Yellow_Leaf_Curl_Virus
# Late_blight
# Leaf_Mold
# Early_blight
# Spider_mites Two-spotted_spider_mite
# Tomato___healthy
# Septoria_leaf_spot

# %%
ls /kaggle/input/datasets/kaustubhb999/tomatoleaf/tomato/train

# %% [markdown]
# классификация

# %% [markdown]
# # 2

# %% [markdown]
# Classes
#
# Leaf smut
# Brown spot
# Bacterial leaf blight

# %%
ls /kaggle/input/datasets/vbookshelf/rice-leaf-diseases/rice_leaf_diseases

# %% [markdown]
# классификация

# %% [markdown]
# # 3

# %%
ls /kaggle/input/datasets/loki4514/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG

# %% [markdown]
# классификация

# %% [markdown]
# # 4

# %%
ls /kaggle/input/datasets/smaranjitghose/corn-or-maize-leaf-disease-dataset/data

# %% [markdown]
# классфиикация
# 0: Обычная ржавчина - 1306 изображений
# 1: Пятно серых листьев - 574 изображения
# 2: Блайт -1146 изображений
# 3: Здоровый - 1162 изображения

# %% [markdown]
# # 5

# %%
ls /kaggle/input/datasets/nirmalsankalana/sugarcane-leaf-disease-dataset

# %%
# классификация

# %% [markdown]
# #  6

# %%
ls /kaggle/input/datasets/aryashah2k/mango-leaf-disease-dataset

# %%
# классификация

# %% [markdown]
# # 7

# %%
ls /kaggle/input/datasets/smaranjitghose/corn-or-maize-leaf-disease-dataset/data

# %% [markdown]
# # 8

# %%
ls /kaggle/input/datasets/smaranjitghose/corn-or-maize-leaf-disease-dataset/data

# %% [markdown]
# # 9

# %%
ls /kaggle/input/datasets/nirmalsankalana/cassava-leaf-disease-classification/data

# %% [markdown]
# # 10 уже склееный

# %%
ls /kaggle/input/datasets/nirmalsankalana/plant-diseases-training-dataset/data

# %% [markdown]
# # 11

# %%
ls "/kaggle/input/datasets/warcoder/potato-leaf-disease-dataset/Potato Leaf Disease Dataset in Uncontrolled Environment"

# %% [markdown]
# # 12 обьеденненный похуже

# %%
# !ls "//kaggle/input/datasets/asheniranga/leaf-disease-dataset-combination/image data/train"

# %% [markdown]
# # 13

# %%
ls /kaggle/input/datasets/mahmoudshaheen1134/lemon-leaf-disease-dataset-lldd/'Original Dataset'

# %% [markdown]
# # 14 сегментация

# %%
ls /kaggle/input/datasets/fakhrealam9537/leaf-disease-segmentation-dataset/data/data

# %% [markdown]
# # 15 просто листья Leaf Disease

# %%
ls /kaggle/input/datasets/sizlingdhairya1/leaf-disease/Datasets

# %% [markdown]
# # 16 cotton leaf disease dataset

# %%
ls /kaggle/input/datasets/ataher/cotton-leaf-disease-dataset/train

# %% [markdown]
# # 17 Banana Leaf Spot Diseases

# %%
ls /kaggle/input/datasets/shifatearman/bananalsd/BananaLSD/OriginalSet

# %% [markdown]
# # 18 flower-leaf-diseases

# %%
ls /kaggle/input/datasets/shuvokumarbasak4004/flower-leaf-diseases-dataset-new-and-update/flower_data/train

# %% [markdown]
# # 19 еще один склееный

# %%
# !ls "/kaggle/input/datasets/lavaman151/plantifydr-dataset/PlantDiseasesDataset"

# %% [markdown]
# # 20

# %%
ls "/kaggle/input/datasets/shashwatwork/identifying-disease-in-tea-leafs/tea sickness dataset"

# %% [markdown]
# # 21

# %%
ls "/kaggle/input/datasets/marquis03/bean-leaf-lesions-classification/train/"

# %% [markdown]
# # 21 рис

# %%
ls "/kaggle/input/datasets/maimunulkjisan/rice-leaf-dataset-from-mendeley-data/Rice Leaf Disease Images"

# %%
ls "/kaggle/input/datasets/dedeikhsandwisaputra/rice-leafs-disease-dataset/RiceLeafsDisease/train"

# %%
ls "/kaggle/input/datasets/vbookshelf/rice-leaf-diseases/rice_leaf_diseases"

# %%
#

# %% [markdown]
# # 22

# %%
ls "/kaggle/input/datasets/ercanavsar/images-of-strawberry-leaves-for-tipburn-detection/dataset - strawberry leaves"

# %% [markdown]
# # 23

# %%
ls /kaggle/input/datasets/codewithsk/cherry-leaf-disease-on-plantcity-2025/Cherry/train

# %%
#

# %% [markdown]
# # 24

# %%
ls /kaggle/input/datasets/alihussainkhan24/red-rot-sugarcane-disease-leaf-dataset/Images
