# %% [markdown]
# ## How to use Kaggle Notebooks
#
# Welcome to the 5-Day AI Agents Intensive Course with Google

# %%
print("Hello World")

# %% [markdown]
# Make sure to run code cells from top to bottom

# %%
from google.adk.agents import Agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")

# %%
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-lite",
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

# %%
from kaggle_secrets import UserSecretsClient
import os

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("✅ Setup complete (Google AI Studio).")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}")

# %% [markdown]
# If you are getting an error that Internet is off in your notebook, you may need to enable it. To do so, go to **Settings** in the menu at the top, then **Turn on Internet**.
